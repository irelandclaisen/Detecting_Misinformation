# %%
"""
This notebook gets labels from a csv file from ASU and scrapes the news articles linked by 
this data set to generate a dataset with text from news articles and labels from the csv file
"""

# %%
import pandas as pd
import pickle
from bs4 import BeautifulSoup
import requests
import time

# %%
# Converts the csv file to a dataframe
df_fake = pd.read_csv('politifact_fake.csv')

# %%
df_fake.head()
# Out:
#                 id                                           news_url  \
# 0  politifact15014          speedtalk.com/forum/viewtopic.php?t=51650
# 1  politifact15156  politics2020.info/index.php/2018/03/13/court-o...
# 2  politifact14745  www.nscdscamps.org/blog/category/parenting/467...
# 3  politifact14355  https://howafrica.com/oscar-pistorius-attempts...
# 4  politifact15371  http://washingtonsources.org/trump-votes-for-d...
#
#                                                title  \
# 0  BREAKING: First NFL Team Declares Bankruptcy O...
# 1  Court Orders Obama To Pay $400 Million In Rest...
# 2  UPDATE: Second Roy Moore Accuser Works For Mic...
# 3         Oscar Pistorius Attempts To Commit Suicide
# 4        Trump Votes For Death Penalty For Being Gay
#
#                                            tweet_ids
# 0  937349434668498944\t937379378006282240\t937380...
# 1  972666281441878016\t972678396575559680\t972827...
# 2  929405740732870656\t929439450400264192\t929439...
# 3  886941526458347521\t887011300278194176\t887023...
# 4  915205698212040704\t915242076681506816\t915249...

# %%
df_real = pd.read_csv('politifact_real.csv')

# %%
# Taking the links from the data frame, we go to the websites and scrape the articles
# which are saved into a list
fake_polifact = []
for index, row in df_fake.iterrows():
    try:
        url = row['news_url']
        if url[0:7] not in ['https:/', 'http://']:
            url = 'https://' + url
        source_code = requests.get(url)
        soup = BeautifulSoup(source_code.text, 'html5lib')
        visible = soup.find_all(text=True)
        text = ''
        for tag in visible:
            if tag.parent.name in ['p', 'a']:
                text += ' ' + tag
        time.sleep(1)
        print(index)
        fake_polifact.append(text)
    except:
        print('Not a valid URL', row['id'])
# Out:
# Not a valid URL politifact15014
# Not a valid URL politifact15156
# Not a valid URL politifact14745
# 3
# 4
# Not a valid URL politifact14404
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# Not a valid URL politifact14233
# Not a valid URL politifact14890
# 15
# 16
# 17
# 18
# 19
# Not a valid URL politifact15052
# Not a valid URL politifact15309
# 22
# Not a valid URL politifact13836
# 24
# Not a valid URL politifact14755
# Not a valid URL politifact13806
# Not a valid URL politifact15164
# Not a valid URL politifact14388
# 29
# Not a valid URL politifact14544
# Not a valid URL politifact13677
# 32
# Not a valid URL politifact14310
# Not a valid URL politifact15130
# Not a valid URL politifact14694
# 36
# 37
# 38
# Not a valid URL politifact14258
# 40
# Not a valid URL politifact15251
# 42
# 43
# 44
# 45
# 46
# 47
# 48
# Not a valid URL politifact13887
# 50
# 51
# Not a valid URL politifact13589
# 53
# 54
# Not a valid URL politifact13565
# Not a valid URL politifact15354
# Not a valid URL politifact14426
# Not a valid URL politifact14565
# 59
# 60
# 61
# Not a valid URL politifact14879
# 63
# Not a valid URL politifact13982
# 65
# 66
# 67
# Not a valid URL politifact14211
# 69
# 70
# 71
# Not a valid URL politifact14700
# Not a valid URL politifact15287
# 74
# 75
# 76
# 77
# 78
# Not a valid URL politifact14052
# Not a valid URL politifact14693
# 81
# 82
# Not a valid URL politifact14205
# Not a valid URL politifact15205
# 85
# 86
# 87
# 88
# 89
# Not a valid URL politifact14837
# Not a valid URL politifact15623
# Not a valid URL politifact15256
# 93
# 94
# Not a valid URL politifact14155
# 96
# 97
# 98
# 99
# 100
# 101
# 102
# 103
# Not a valid URL politifact13744
# 105
# 106
# 107
# 108
# 109
# Not a valid URL politifact14128
# 111
# 112
# 113
# 114
# 115
# Not a valid URL politifact13936
# 117
# 118
# Not a valid URL politifact14644
# Not a valid URL politifact14859
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 130
# Not a valid URL politifact13544
# 132
# 133
# 134
# 135
# 136
# 137
# Not a valid URL politifact14831
# 139
# Not a valid URL politifact14062
# 141
# 142
# Not a valid URL politifact15360
# Not a valid URL politifact14161
# 145
# Not a valid URL politifact14259
# 147
# 148
# 149
# 150
# 151
# Not a valid URL politifact13608
# 153
# 154
# 155
# 156
# 157
# Not a valid URL politifact14238
# 159
# 160
# 161
# 162
# 163
# 164
# Not a valid URL politifact15224
# 166
# 167
# 168
# Not a valid URL politifact14311
# 170
# Not a valid URL politifact14500
# 172
# Not a valid URL politifact14481
# 174
# Not a valid URL politifact14856
# 176
# 177
# 178
# 179
# 180
# 181
# Not a valid URL politifact13703
# 183
# 184
# Not a valid URL politifact14777
# 186
# 187
# 188
# 189
# 190
# 191
# Not a valid URL politifact14085
# 193
# Not a valid URL politifact14207
# Not a valid URL politifact13934
# 196
# Not a valid URL politifact14265
# 198
# Not a valid URL politifact14190
# 200
# Not a valid URL politifact14145
# 202
# 203
# 204
# 205
# 206
# 207
# Not a valid URL politifact14818
# Not a valid URL politifact15206
# 210
# 211
# 212
# 213
# 214
# 215
# 216
# 217
# Not a valid URL politifact14026
# 219
# Not a valid URL politifact14756
# 221
# Not a valid URL politifact15270
# 223
# Not a valid URL politifact15534
# 225
# 226
# 227
# Not a valid URL politifact14620
# Not a valid URL politifact14406
# 230
# 231
# 232
# 233
# Not a valid URL politifact14040
# 235
# Not a valid URL politifact14771
# 237
# Not a valid URL politifact15539
# 239
# 240
# Not a valid URL politifact14993
# 242
# 243
# Not a valid URL politifact14427
# Not a valid URL politifact15399
# 246
# 247
# 248
# 249
# 250
# 251
# 252
# 253
# 254
# 255
# Not a valid URL politifact14436
# 257
# 258
# Not a valid URL politifact14516
# Not a valid URL politifact14885
# 261
# 262
# 263
# 264
# 265
# 266
# 267
# 268
# 269
# 270
# 271
# Not a valid URL politifact13584
# 273
# Not a valid URL politifact15540
# 275
# 276
# 277
# 278
# Not a valid URL politifact14003
# 280
# 281
# 282
# Not a valid URL politifact14166
# 284
# 285
# 286
# 287
# 288
# 289
# 290
# 291
# Not a valid URL politifact14621
# 293
# 294
# 295
# Not a valid URL politifact13724
# 297
# 298
# 299
# 300
# Not a valid URL politifact14887
# 302
# 303
# 304
# 305
# 306
# Not a valid URL politifact15398
# 308
# 309
# 310
# 311
# 312
# 313
# 314
# 315
# 316
# 317
# 318
# 319
# 320
# 321
# 322
# 323
# 324
# Not a valid URL politifact13820
# Not a valid URL politifact14905
# 327
# Not a valid URL politifact15201
# 329
# 330
# 331
# Not a valid URL politifact13557
# 333
# Not a valid URL politifact15294
# 335
# 336
# Not a valid URL politifact15210
# 338
# 339
# 340
# 341
# 342
# Not a valid URL politifact15232
# 344
# Not a valid URL politifact15334
# 346
# 347
# 348
# Not a valid URL politifact13576
# 350
# 351
# Not a valid URL politifact15242
# Not a valid URL politifact14116
# 354
# Not a valid URL politifact14947
# 356
# 357
# 358
# 359
# 360
# 361
# 362
# 363
# Not a valid URL politifact14289
# 365
# Not a valid URL politifact13987
# 367
# 368
# Not a valid URL politifact13720
# 370
# 371
# 372
# 373
# Not a valid URL politifact14770
# Not a valid URL politifact13815
# 376
# 377
# Not a valid URL politifact14402
# Not a valid URL politifact14330
# 380
# 381
# 382
# 383
# 384
# 385
# 386
# 387
# Not a valid URL politifact15592
# 389
# Not a valid URL politifact15379
# 391
# Not a valid URL politifact13601
# 393
# Not a valid URL politifact14789
# 395
# 396
# 397
# 398
# Not a valid URL politifact15037
# 400
# Not a valid URL politifact15307
# 402
# 403
# 404
# 405
# Not a valid URL politifact15570
# 407
# Not a valid URL politifact15141
# 409
# Not a valid URL politifact15147
# 411
# 412
# 413
# Not a valid URL politifact15301
# Not a valid URL politifact14884
# Not a valid URL politifact15188
# 417
# 418
# 419
# 420
# Not a valid URL politifact14992
# 422
# Not a valid URL politifact13475
# Not a valid URL politifact15356
# Not a valid URL politifact14998
# Not a valid URL politifact14362
# 427
# 428
# 429
# Not a valid URL politifact13560
# Not a valid URL politifact15030

# %%
# Saves the list into a dataframe
df_poli = pd.DataFrame(fake_polifact, columns = ['text'])

# %%
# Remove articles that are too short.  Possibly not a real article
# or did not get access
df_poli2 = df_poli[df_poli['text'].str.len() >200]

# %%
df_poli2.head()
# Out:
#                                                 text
# 1   About Contact Privacy Policy Disclaimer \n\t ...
# 2   Adrenalin Boost Alternative Health Android An...
# 3   \n \n \n RELIGION MIND  \n home Buddhism Chri...
# 4   \n \n Home Politics President Trump The Supre...
# 5     Before It's News Featured Economy Health Be...

# %%
# Generates a column 'true' where all the values are 0 because all the articles
# in this dataframe have been labelled fake
df_poli2['true'] = 0
# Out:
# <ipython-input-74-be4ba61bf6b4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_poli2['true'] = 0

# %%
# Cleans up text in dataframe, like removing extraneous characters, punctuation, etc.
import re
import string

cleanup = lambda x: re.sub("U.S", 'us', x)
cleanup2 = lambda x: re.sub("\n", '', x)
cleanup3 = lambda x: re.sub("\t", '', x)
apostrophe = lambda x: re.sub("\'", '', x)
alphanumeric = lambda x: re.sub('\w*\d\w*', ' ', x)
punc_lower = lambda x: re.sub('[%s]' % re.escape(string.punctuation), ' ', x.lower())

#df['text'] = df['Text'].map(us).map(apostrophe).map(alphanumeric).map(punc_lower)
df_poli2['text'] = df_poli2['text'].map(cleanup).map(cleanup2).map(cleanup3).map(apostrophe).map(alphanumeric)

# %%
# Saves the cleaned up dataframe into a pickle file
with open('politifact.pickle', 'wb') as to_write:
    pickle.dump(df_poli2, to_write)
